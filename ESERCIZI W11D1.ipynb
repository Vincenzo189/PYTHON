# %%
import os
import dotenv
import sqlalchemy
import pandas as pd

dotenv.load_dotenv(dotenv_path="cred.env", override=True)

username = os.getenv("username")
password = os.getenv("password")
host = os.getenv("host")
dbname = os.getenv("dbname")

connection_string = f"mysql+pymysql://{username}:{password}@{host}/{dbname}"
print(connection_string)

db_engine = sqlalchemy.create_engine(connection_string)
# Out:
# mysql+pymysql://studente_dapt:Ep1c0d3!!D4t4**4n4lys1s@epicode-data-pt-mysql.cvetyjye2qbl.eu-central-1.rds.amazonaws.com/AdventureWorksDW

# %%
mappa = pd.read_csv("dataset/altri_dataset/Mappa-dei-pub-circoli-locali-in-Italia.csv", encoding="latin1", sep=";")

# %%
mappa
# Out:
#             Comune                       Provincia   Regione             Nome  \
# 0            ALTRO                           ALTRO     ALTRO              NaN
# 1            ALTRO                           ALTRO     ALTRO      Lenny's Pub
# 2            ALTRO                           ALTRO     ALTRO  Murrayfield Pub
# 3            ALTRO                           ALTRO     ALTRO           Snop?e
# 4     ALA DI STURA  CITTA' METROPOLITANA DI TORINO  Piemonte              NaN
# ...            ...                             ...       ...              ...
# 2630      BARLETTA           BARLETTA-ANDRIA-TRANI    Puglia      Santa Croce
# 2631     BISCEGLIE           BARLETTA-ANDRIA-TRANI    Puglia      Auld Dublin
# 2632     BISCEGLIE           BARLETTA-ANDRIA-TRANI    Puglia            Ferus
# 2633         TRANI           BARLETTA-ANDRIA-TRANI    Puglia          Re Artù
# 2634         TRANI           BARLETTA-ANDRIA-TRANI    Puglia     Well's Fargo
#
# ...

# %%
#quanti dati ci sono in totale?

# %%
mappa.shape
# Out:
# (2635, 9)

# %%
mappa.size
# Out:
# 23715

# %%
#quali sono i metadati?

# %%
mappa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2635 entries, 0 to 2634
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Comune                           2635 non-null   object
#  1   Provincia                        2635 non-null   object
#  2   Regione                          2635 non-null   object
#  3   Nome                             2337 non-null   object
#  4   Anno inserimento                 2635 non-null   int64
#  5   Data e ora inserimento           2635 non-null   object
#  6   Identificatore in OpenStreetMap  2635 non-null   int64
#  7   Longitudine                      2635 non-null   float64
#  8   Latitudine                       2635 non-null   float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 185.4+ KB

# %%
mappa.describe()
# Out:
#        Anno inserimento  Identificatore in OpenStreetMap  Longitudine  \
# count       2635.000000                     2.635000e+03  2635.000000
# mean        2012.831120                     1.863583e+09    11.440212
# std            1.911466                     1.059639e+09     2.338170
# min         2007.000000                     3.203094e+07     6.708958
# 25%         2012.000000                     9.328297e+08     9.225153
# 50%         2013.000000                     1.790185e+09    11.387645
# 75%         2014.000000                     2.651045e+09    12.604773
# max         2016.000000                     4.012443e+09    18.444577
#
#         Latitudine
# count  2635.000000
# mean     43.997322
# std       2.137994
# min      36.680786
# 25%      42.351325
# 50%      44.905865
# 75%      45.598054
# max      46.983781

# %%
mappa.dtypes
# Out:
# Comune                              object
# Provincia                           object
# Regione                             object
# Nome                                object
# Anno inserimento                     int64
# Data e ora inserimento              object
# Identificatore in OpenStreetMap      int64
# Longitudine                        float64
# Latitudine                         float64
# dtype: object

# %%
#stampiamo il primo elemento

# %%
mappa.head(1)
# Out:
#   Comune Provincia Regione Nome  Anno inserimento Data e ora inserimento  \
# 0  ALTRO     ALTRO   ALTRO  NaN              2011   2011-06-25T23:17:43Z
#
#    Identificatore in OpenStreetMap  Longitudine  Latitudine
# 0                       1339088150    13.733257    45.57583

# %%
#stampiamo l'ultimo elemento

# %%
mappa.tail(1)
# Out:
#      Comune              Provincia Regione          Nome  Anno inserimento  \
# 2634  TRANI  BARLETTA-ANDRIA-TRANI  Puglia  Well's Fargo              2009
#
#      Data e ora inserimento  Identificatore in OpenStreetMap  Longitudine  \
# 2634   2009-08-10T12:44:03Z                        387223648    16.436765
#
#       Latitudine
# 2634   41.267264

# %%
#riusciamo a stampare un elemento a caso?

# %%
mappa.sample(1)
# Out:
#       Comune Provincia   Regione      Nome  Anno inserimento  \
# 2458  SINNAI  CAGLIARI  Sardegna  Il Bazar              2008
#
#      Data e ora inserimento  Identificatore in OpenStreetMap  Longitudine  \
# 2458   2008-11-24T22:39:59Z                        314063179     9.197443
#
#       Latitudine
# 2458   39.299024

# %%
#quali sono gli anni di inserimento presenti?

# %%
sorted (mappa["Anno inserimento"].unique())
# Out:
# [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016]

# %%
#quante attività ci sono nel quadrato di longitudine 9-10 e latitudine 45-46?

# %%
filtro = mappa[
        (mappa['Longitudine'] >= 9) & (mappa['Longitudine'] <= 10) &
        (mappa['Latitudine'] >= 45) & (mappa['Latitudine'] <= 46)
]

filtro.shape[0]
# Out:
# 306

# %%
#quante attività ci sono nella provincia di Vicenza?

# %%
filtro = mappa[
    (mappa['Provincia'] == "VICENZA")
    ]
filtro.shape[0]
# Out:
# 73

# %%
#quante enoteche ci sono, e come si chiamano?

# %%
lista_enoteche = []
for nome in mappa["Nome"]:
    if pd.notna(nome):
        if "enoteca" in nome.lower():
            lista_enoteche.append(nome)
            print (nome)

print ("Ci sono", len(lista_enoteche), "enoteche")
# Out:
# Enoteca con Cucina""Tirolin""
# Concordia Enoteca
# Enoteca Umberto
# Enoteca ""Al Brindisi""
# Enoteca ""da Massimo""
# Enoteca Il Violino Rosso
# Ci sono 6 enoteche

# %%
#OPPURE

# %%
filtro = mappa["Nome"].str.contains('Enoteca')
filtro = filtro.fillna(False)
mappa.loc[filtro]
# Out:
# C:\Users\2021\AppData\Local\Temp\ipykernel_1888\2690430468.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   filtro = filtro.fillna(False)
#                    Comune                       Provincia         Regione  \
# 64                 TORINO  CITTA' METROPOLITANA DI TORINO        Piemonte
# 496                MILANO  CITTA' METROPOLITANA DI MILANO       Lombardia
# 1003                 MALO                         VICENZA          Veneto
# 1491              FERRARA                         FERRARA  Emilia-Romagna
# 1492              FERRARA                         FERRARA  Emilia-Romagna
# 1723  CASCIANA TERME LARI                            PISA         Toscana
#
#                                Nome  Anno inserimento Data e ora inserimento  \
# ...

# %%
#quante attività ci sono in Abruzzo e Lazio assieme?

# %%
filtro = mappa[
    (mappa['Regione'] == "Lazio") | 
    (mappa['Regione'] == "Abruzzo")]
filtro.shape[0]
# Out:
# 337

# %%
#ESERCIZIO INSURANCE
#Visualizziamone le dimensioni, un'anteprima, e osserviamo i nomi di colonna;

# %%
insurance = pd.read_csv("dataset/beginner_datasets/insurance.csv")
insurance
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
insurance.shape
# Out:
# (1338, 7)

# %%
insurance.size
# Out:
# 9366

# %%
insurance.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
#Quali sono le medie di charges rispetto a region? Ci sono differenze significative?

# %%
insurance.groupby("region")["charges"].mean()
# Out:
# region
# northeast    13406.384516
# northwest    12417.575374
# southeast    14735.411438
# southwest    12346.937377
# Name: charges, dtype: float64

# %%
#E rispetto a smoker? E a sex?

# %%
insurance.groupby("smoker")["charges"].mean()
# Out:
# smoker
# no      8434.268298
# yes    32050.231832
# Name: charges, dtype: float64

# %%
insurance.groupby("sex")["charges"].mean()
# Out:
# sex
# female    12569.578844
# male      13956.751178
# Name: charges, dtype: float64

# %%
#Quali sono i descrittori statistici di bmi? Quali sono minimo, media e massimo di charges rispetto ai diversi quartili dei valori di bmi?

# %%
insurance["bmi"].describe()
# Out:
# count    1338.000000
# mean       30.663397
# std         6.098187
# min        15.960000
# 25%        26.296250
# 50%        30.400000
# 75%        34.693750
# max        53.130000
# Name: bmi, dtype: float64

# %%
insurance.groupby("bmi")["charges"].describe()
# Out:
#         count          mean          std          min          25%  \
# bmi
# 15.960    1.0   1694.796400          NaN   1694.79640   1694.79640
# 16.815    2.0   4904.000350  2455.844784   3167.45585   4035.72810
# 17.195    1.0  14455.644050          NaN  14455.64405  14455.64405
# 17.290    3.0   7813.353433  4619.986089   3732.62510   5305.30260
# 17.385    1.0   2775.192150          NaN   2775.19215   2775.19215
# ...       ...           ...          ...          ...          ...
# 48.070    1.0   9432.925300          NaN   9432.92530   9432.92530
# 49.060    1.0  11381.325400          NaN  11381.32540  11381.32540
# 50.380    1.0   2438.055200          NaN   2438.05520   2438.05520
# 52.580    1.0  44501.398200          NaN  44501.39820  44501.39820
# 53.130    1.0   1163.462700          NaN   1163.46270   1163.46270
#
#                 50%          75%          max
# bmi
# 15.960   1694.79640   1694.79640   1694.79640
# 16.815   4904.00035   5772.27260   6640.54485
# ...

# %%
#CARICHIAMO IRIS.CV

# %%
iris = pd.read_csv("dataset/beginner_datasets/iris.csv")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#La media della lunghezza dei petali di tutto il dataset

# %%
iris["petal_length"].mean()
# Out:
# 3.758666666666666

# %%
#La media della lunghezza dei petali per ogni specie di Iris

# %%
iris.groupby("species")["petal_length"].mean()
# Out:
# species
# Iris-setosa        1.464
# Iris-versicolor    4.260
# Iris-virginica     5.552
# Name: petal_length, dtype: float64

# %%
#Media, minimo e massimo della larghezza dei sepali per ogni specie

# %%
statistiche_sepali = (
    iris.groupby('species')['sepal_width']
      .agg(avg='mean', min='min', max='max')
      .reset_index())
print(statistiche_sepali)
# Out:
#            species    avg  min  max
# 0      Iris-setosa  3.418  2.3  4.4
# 1  Iris-versicolor  2.770  2.0  3.4
# 2   Iris-virginica  2.974  2.2  3.8

# %%
# dataset wine.csv

# %%
wine = pd.read_csv("dataset/beginner_datasets/wine.csv")
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
#Qual è la media di concentrazione alcolica per ogni qualità? Ci sono differenze? E rispetto alla media totale?

# %%
wine.groupby("quality")["alcohol"].mean() #più è alta la qualità più c'è concentrazione alcolica
# Out:
# quality
# 3    10.215000
# 4    10.180093
# 5     9.837783
# 6    10.587553
# 7    11.386006
# 8    11.678756
# 9    12.180000
# Name: alcohol, dtype: float64

# %%
wine["alcohol"].mean()
# Out:
# 10.491800831149453

# %%
#C'è differenza nella concentrazione alcolica per vini bianchi e vini rossi?

# %%
wine.groupby("type")["alcohol"].mean() #nei vini bianchi la concentrazione alcolica è un po' piu alta
# Out:
# type
# red      10.422983
# white    10.514267
# Name: alcohol, dtype: float64

# %%
#Rifacendo le analisi dei due punti precedenti ma per il pH, cambia qualcosa?

# %%
wine.groupby("quality")["pH"].mean() #piu si scende o si sale di qualità più il ph aumenta
# Out:
# quality
# 3    3.257667
# 4    3.231620
# 5    3.212189
# 6    3.217726
# 7    3.228072
# 8    3.223212
# 9    3.308000
# Name: pH, dtype: float64

# %%
wine["pH"].mean()
# Out:
# 3.2185008465445586

# %%
wine.groupby("type")["pH"].mean() #nei vini rossi c'è maggiore ph
# Out:
# type
# red      3.311113
# white    3.188267
# Name: pH, dtype: float64

# %%
#E per i solfati?

# %%
wine.groupby("quality")["sulphates"].mean() #piu si scende o si sale di qualità più i solfati aumentano
# Out:
# quality
# 3    0.506333
# 4    0.505648
# 5    0.526403
# 6    0.532549
# 7    0.547025
# 8    0.512487
# 9    0.466000
# Name: sulphates, dtype: float64

# %%
wine["sulphates"].mean()
# Out:
# 0.5312682776666154

# %%
wine.groupby("type")["sulphates"].mean() #nei vini rossi ci sono più solfati
# Out:
# type
# red      0.658149
# white    0.489847
# Name: sulphates, dtype: float64

# %%
#CSV BOSTON CITY

# %%
boston = pd.read_csv("dataset/beginner_datasets/boston.csv")
boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
#La media del prezzo delle case cambia a seconda della distanza dal fiume Charles?

# %%
boston.groupby("chas")["medv"].mean() #se costeggia il fiume la casa costa di piu
# Out:
# chas
# 0    22.093843
# 1    28.440000
# Name: medv, dtype: float64

# %%
#Si nota una correlazione tra il tasso di criminalità e il valore delle abitazioni? Come si può spiegare il risultato?

# %%
boston['crim'].corr(boston['medv']) #all’aumentare della criminalità, diminuisce il valore delle case.
# Out:
# -0.38830460858681143

# %%
#Qual è la media del numero di stanze rispetto al rapporto alunni-insegnanti? E del valore delle case?
#Appare esserci una qualche correlazione? Come si può spiegare il risultato?

# %%
boston.groupby("ptratio")["rm"].mean() # nelle aree con un rapporto alunni-insegnanti più basso le case tendono ad avere più stanze.
# Out:
# ptratio
# 12.6    7.222667
# 13.0    7.406167
# 13.6    7.923000
# 14.4    7.875000
# 14.7    6.246235
# 14.8    6.752333
# 14.9    7.311250
# 15.1    6.816000
# 15.2    6.421923
# 15.3    6.705333
# 15.5    7.241000
# 15.6    6.702000
# 15.9    6.997000
# 16.0    6.230600
# 16.1    6.428800
# 16.4    6.139667
# 16.6    6.344188
# 16.8    6.146750
# 16.9    6.016400
# 17.0    6.868250
# 17.3    6.383000
# 17.4    7.212333
# 17.6    6.822429
# 17.8    6.496130
# 17.9    6.134818
# 18.0    7.218600
# 18.2    6.283000
# 18.3    6.520500
# 18.4    6.285938
# 18.5    6.288750
# 18.6    6.111588
# 18.7    6.406556
# 18.8    5.956000
# 18.9    5.785667
# 19.0    6.453750
# 19.1    6.234882
# 19.2    6.053632
# 19.6    6.224000
# 19.7    6.303250
# 20.1    5.585400
# 20.2    6.024021
# 20.9    6.266273
# 21.0    6.039778
# 21.1    5.888000
# 21.2    6.028533
# 22.0    5.799500
# Name: rm, dtype: float64

# %%
boston['rm'].corr(boston['ptratio'])
# Out:
# -0.3555014945590847

# %%
boston.groupby("ptratio")["medv"].mean() # dove il rapporto alunni-insegnanti è più basso, il valore delle case è mediamente più alto
# Out:
# ptratio
# 12.6    32.733333
# 13.0    38.025000
# 13.6    50.000000
# 14.4    50.000000
# 14.7    25.717647
# 14.8    25.433333
# 14.9    40.475000
# 15.1    31.600000
# 15.2    26.276923
# 15.3    26.066667
# 15.5    32.700000
# 15.6    30.100000
# 15.9    30.250000
# 16.0    24.320000
# 16.1    24.880000
# 16.4    23.216667
# 16.6    23.856250
# 16.8    22.150000
# 16.9    19.640000
# 17.0    30.600000
# 17.3    24.700000
# 17.4    33.544444
# 17.6    30.700000
# 17.8    26.956522
# 17.9    22.363636
# 18.0    33.100000
# 18.2    22.150000
# 18.3    27.100000
# 18.4    23.131250
# 18.5    23.800000
# 18.6    24.335294
# 18.7    25.122222
# 18.8    17.350000
# 18.9    20.100000
# 19.0    24.900000
# 19.1    22.894118
# 19.2    22.805263
# 19.6    22.575000
# 19.7    21.787500
# 20.1    12.800000
# 20.2    16.611429
# 20.9    21.118182
# 21.0    17.351852
# 21.1    18.900000
# 21.2    17.093333
# 22.0    19.400000
# Name: medv, dtype: float64

# %%
boston['medv'].corr(boston['ptratio'])
# Out:
# -0.5077866855375616

# %%
#Rispetto all'accessibilità alle autostrade, cambia qualcosa la media delle età delle abitazioni? E del numero di stanze? E delle tasse?

# %%
boston.groupby("rad")["age"].mean() #l'eta tende a diminuire all’aumentare dell’accessibilità
# Out:
# rad
# 1     45.025000
# 2     64.770833
# 3     49.310526
# 4     60.841818
# 5     69.223478
# 6     60.142308
# 7     40.141176
# 8     67.350000
# 24    89.805303
# Name: age, dtype: float64

# %%
boston['age'].corr(boston['rad'])
# Out:
# 0.4560224517516137

# %%
boston.groupby("rad")["rm"].mean() # il numero di stanze aumenta con l’aumentare dell’accessibilità
# Out:
# rad
# 1     6.555850
# 2     6.649958
# 3     6.473026
# 4     6.133118
# 5     6.393157
# 6     6.104731
# 7     6.647765
# 8     6.950792
# 24    6.022152
# Name: rm, dtype: float64

# %%
boston['rm'].corr(boston['rad'])
# Out:
# -0.20984666776610875

# %%
boston.groupby("rad")["tax"].mean() #le tasse aumentano all'aumentare dell'accessibilità
# Out:
# rad
# 1     291.450000
# 2     260.666667
# 3     246.078947
# 4     335.981818
# 5     331.843478
# 6     372.884615
# 7     304.411765
# 8     301.250000
# 24    666.000000
# Name: tax, dtype: float64

# %%
boston['tax'].corr(boston['rad'])
# Out:
# 0.9102281885331835

# %%
# ABBIAMO DUE DATAFRAME

# %%
dipendenti_df = pd.DataFrame({
    'dipendente_id': [101, 102, 103, 104, 105], 
    'nome': ['Alice', 'Bob', 'Charlie', 'David', 'Emma'], 
    'dipartimento_id': [1, 2, 1, 2, 3] 
})

# %%
dipartimento_df = pd.DataFrame({ 
    'dipartimento_id': [1, 2, 3], 
    'nome_dipartimento': ['HR', 'IT', 'Finance'], 
    'localita': ['New York', 'San Francisco', 'Chicago'] 
})

# %%
# Unire questi DataFrame usando la funzione .merge()

# %%
pd.merge(dipendenti_df, dipartimento_df, on = "dipartimento_id", how = "inner")
# Out:
#    dipendente_id     nome  dipartimento_id nome_dipartimento       localita
# 0            101    Alice                1                HR       New York
# 1            102      Bob                2                IT  San Francisco
# 2            103  Charlie                1                HR       New York
# 3            104    David                2                IT  San Francisco
# 4            105     Emma                3           Finance        Chicago

# %%
#Per ogni DataFrame, trasformare la colonna department_id nell'indice, facendo in modo che la modifica sia permanente;
#poi unire i due dataset mediante il metodo .join()

# %%
dipendenti_df = dipendenti_df.set_index("dipartimento_id")

# %%
dipartimento_df = dipartimento_df.set_index("dipartimento_id")

# %%
dipendenti_df.join(dipartimento_df, how='left')
# Out:
#                  dipendente_id     nome nome_dipartimento       localita
# dipartimento_id
# 1                          101    Alice                HR       New York
# 2                          102      Bob                IT  San Francisco
# 1                          103  Charlie                HR       New York
# 2                          104    David                IT  San Francisco
# 3                          105     Emma           Finance        Chicago

# %%
#Ci sono differenze nel risultato? Quali? Perché?

# %%
#ci sono differenze perchè ora non ci sono chiavi primarie uniche (indici duplicati)

# %%
#importiamo le tabelle dimemployee e dimemployeesalesterritory

# %%
query = "SELECT * FROM dimemployee"
dimemployee = pd.read_sql(query, db_engine)
dimemployee
# Out:
#      EmployeeKey  ParentEmployeeKey  EmployeeNationalIDAlternateKey  \
# 0              1               18.0                        14417807
# 1              2                7.0                       253022876
# 2              3               14.0                       509647174
# 3              4                3.0                       112457891
# 4              5                3.0                       112457891
# ..           ...                ...                             ...
# 291          292              290.0                       134219713
# 292          293              272.0                        90836195
# 293          294              277.0                       481044938
# 294          295              290.0                       954276278
# 295          296              294.0                       758596752
#
#      ParentEmployeeNationalIDAlternateKey FirstName           LastName  \
# 0                             446466105.0       Guy            Gilbert
# ...

# %%
query = "SELECT * FROM dimemployeesalesterritory"
dimemployeesalesterritory = pd.read_sql(query, db_engine)
dimemployeesalesterritory
# Out:
#     EmployeeKey  SalesTerritoryKey
# 0           272                  1
# 1           277                  1
# 2           286                  1
# 3           289                  1
# 4           293                  1
# 5           272                  2
# 6           277                  2
# 7           281                  2
# 8           272                  3
# 9           277                  3
# 10          281                  3
# 11          282                  3
# 12          283                  3
# 13          272                  4
# 14          277                  4
# 15          282                  4
# 16          286                  4
# 17          287                  4
# 18          272                  5
# 19          277                  5
# 20          281                  5
# 21          285                  5
# 22          272                  6
# 23          277                  6
# 24          284                  6
# 25          288                  6
# ...

# %%
#Effettuiamo un join tra i due DataFrame usando le colonne EmployeeKey

# %%
dimemployee = dimemployee.set_index("EmployeeKey")

# %%
dimemployee1 = dimemployee.reset_index()

# %%
dimemployeesalesterritory = dimemployeesalesterritory.set_index("EmployeeKey")

# %%
dimemployeesalesterritory1 = dimemployeesalesterritory.reset_index()

# %%
employee_salesterritory1 = pd.merge(dimemployee1, dimemployeesalesterritory1, on = "EmployeeKey", how = "inner")
employee_salesterritory1
# Out:
#     EmployeeKey  ParentEmployeeKey  EmployeeNationalIDAlternateKey  \
# 0           272              277.0                       502097814
# 1           272              277.0                       502097814
# 2           272              277.0                       502097814
# 3           272              277.0                       502097814
# 4           272              277.0                       502097814
# 5           272              277.0                       502097814
# 6           277              277.0                       112432117
# 7           277              277.0                       112432117
# 8           277              277.0                       112432117
# 9           277              277.0                       112432117
# 10          277              277.0                       112432117
# 11          277              277.0                       112432117
# 12          277              277.0                       112432117
# ...

# %%
#Controlliamo la dimensione del DataFrame risultante: è quella attesa?

# %%
employee_salesterritory1.size
# Out:
# 1131

# %%
employee_salesterritory1.shape
# Out:
# (39, 29)

# %%
#Importiamo ora la tabella dimsalesterritory ed effettuiamo un join tra questa 
#e il DataFrame risultante della join precedente, usando le colonne SalesTerritoryKey

# %%
query = "SELECT * FROM dimsalesterritory"
dimsalesterritory = pd.read_sql(query, db_engine)
dimsalesterritory
# Out:
#     SalesTerritoryKey  SalesTerritoryAlternateKey SalesTerritoryRegion  \
# 0                   1                           1            Northwest
# 1                   2                           2            Northeast
# 2                   3                           3              Central
# 3                   4                           4            Southwest
# 4                   5                           5            Southeast
# 5                   6                           6               Canada
# 6                   7                           7               France
# 7                   8                           8              Germany
# 8                   9                           9            Australia
# 9                  10                          10       United Kingdom
# 10                 11                           0         Corporate HQ
#
#    SalesTerritoryCountry SalesTerritoryGroup  \
# 0          United States       North America
# ...

# %%
vendite_complete = pd.merge(employee_salesterritory, dimsalesterritory, on = "SalesTerritoryKey", how = "inner")
vendite_complete
# Out:
#     ParentEmployeeKey  EmployeeNationalIDAlternateKey  \
# 0               277.0                       502097814
# 1               277.0                       502097814
# 2               277.0                       502097814
# 3               277.0                       502097814
# 4               277.0                       502097814
# 5               277.0                       502097814
# 6               277.0                       112432117
# 7               277.0                       112432117
# 8               277.0                       112432117
# 9               277.0                       112432117
# 10              277.0                       112432117
# 11              277.0                       112432117
# 12              277.0                       112432117
# 13              277.0                       112432117
# 14              277.0                       112432117
# 15              277.0                       112432117
# ...

# %%
#Su questo DataFrame contare quanti dipendenti ci sono per ogni paese (country) e per ogni regione (region)

# %%
dipendenti_per_paese = vendite_complete.groupby("SalesTerritoryCountry")["FirstName"].count()
dipendenti_per_paese
# Out:
# SalesTerritoryCountry
# Australia          3
# Canada             4
# France             4
# Germany            3
# United Kingdom     3
# United States     22
# Name: FirstName, dtype: int64

# %%
dipendenti_per_regione = vendite_complete.groupby("SalesTerritoryRegion")["FirstName"].count()
dipendenti_per_regione
# Out:
# SalesTerritoryRegion
# Australia         3
# Canada            4
# Central           5
# France            4
# Germany           3
# Northeast         3
# Northwest         5
# Southeast         4
# Southwest         5
# United Kingdom    3
# Name: FirstName, dtype: int64

# %%
#Valutiamo la media del BaseRate per ogni paese: ci sono differenze?

# %%
media_tasso_base = vendite_complete.groupby("SalesTerritoryCountry")["BaseRate"].mean()
media_tasso_base
# Out:
# SalesTerritoryCountry
# Australia         47.764433
# Canada            41.592550
# France            41.592550
# Germany           47.764433
# United Kingdom    47.764433
# United States     39.909309
# Name: BaseRate, dtype: float64
